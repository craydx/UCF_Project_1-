# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import hvplot.pandas
 
# Read the data and the study results
diabetes_df = pd.read_csv('diabetes_prediction_dataset.csv')
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
#Determine type of data
diabetes_df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
#Age correct for type 2 Diabetes
age_corrected_df = diabetes_df [diabetes_df.age >=30]
age_corrected_df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 6  Female  44.0             0              0           never  19.31
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 3          5.0                  155         0
# 4          4.8                  155         0
# 6          6.5                  200         1

# %%
#correct for people diagnosed with diabetes
age_corrected_diabetics_df = age_corrected_df[age_corrected_df.diabetes ==1]
age_corrected_diabetics_df.head()
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6   Female  44.0             0              0           never  19.31
# 26    Male  67.0             0              1     not current  27.32
# 38    Male  50.0             1              0         current  27.32
# 40    Male  73.0             0              0          former  25.91
# 53  Female  53.0             0              0          former  27.32
#
#     HbA1c_level  blood_glucose_level  diabetes
# 6           6.5                  200         1
# 26          6.5                  200         1
# 38          5.7                  260         1
# 40          9.0                  160         1
# 53          7.0                  159         1

# %%
#narrow down female for graphs
female_diabetics_df = age_corrected_diabetics_df[(age_corrected_diabetics_df ['gender']== 'Female')]
female_diabetics_df.head()
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6   Female  44.0             0              0           never  19.31
# 53  Female  53.0             0              0          former  27.32
# 59  Female  67.0             0              0           never  63.48
# 87  Female  36.0             0              0         current  32.27
# 94  Female  60.0             0              0           never  27.32
#
#     HbA1c_level  blood_glucose_level  diabetes
# 6           6.5                  200         1
# 53          7.0                  159         1
# 59          8.8                  155         1
# 87          6.2                  220         1
# 94          7.5                  300         1

# %%
# scatter plot
female_diabetics_df.plot(kind='scatter',
        x='age',
        y='bmi',
        color='red')
 
# set the title
plt.title('Female Diabetics')
 
# show the plot
plt.show()



# #Linear regression on scatter plot for Female diabetics
# female_diabetics_df['gender'] = female_diabetics_df['gender'.astype ['int32']
# plt.scatter(     
#     age,
#     hypertension,
#     edgecolor="black",
#     linewidths=1,
#     marker="o", 
#     alpha=0.8,
#     label="Cities"
# )
# #Labels and Grid
# plt.title("Diabetes vs Age (years)")
# plt.xlabel("Confirmed Female Diabetics")
# plt.ylabel("Age (years) ")
# plt.grid(True)

# #Regression stats and plot line
# (slope, intercept, rvalue, pvalue, stderr) =linregress(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"] )
# regress_values = (northern_hemi_df["Lat"]) * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.plot((northern_hemi_df["Lat"]),regress_values,"r-")
# plt.annotate(line_eq,(5.8,-15),fontsize=15,color="red")

# # Show plot and Pearson r
# plt.show()
# correlation = st.pearsonr((northern_hemi_df["Lat"]),northern_hemi_df["Max Temp"])
# print(correlation)

# %%
#narrow down males for graphs
male_diabetics_df = age_corrected_diabetics_df[(age_corrected_diabetics_df ['gender']== 'Male')]
male_diabetics_df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 26   Male  67.0             0              1     not current  27.32
# 38   Male  50.0             1              0         current  27.32
# 40   Male  73.0             0              0          former  25.91
# 55   Male  50.0             0              0          former  37.16
# 81   Male  57.0             0              0         No Info  27.32
#
#     HbA1c_level  blood_glucose_level  diabetes
# 26          6.5                  200         1
# 38          5.7                  260         1
# 40          9.0                  160         1
# 55          9.0                  159         1
# 81          8.2                  126         1

# %%
 
# show the plot
plt.show()

# # Linear regression on Female Diabetics with scatter plot

plt.scatter(     
     northern_hemi_df["Lat"],
     northern_hemi_df["Max Temp"],
     edgecolor="black",
     linewidths=1,
     marker="o", 
     alpha=0.8,
     label="Cities"
 )
# #Labels and Grid
# plt.title("Northern Latitudes vs. Temperature (C) (%s)" % time.strftime("%Y-%m-%d"))
# plt.xlabel("Northern Latitudes")
# plt.ylabel("Temperature(C) ")
# plt.grid(True)

# #Regression stats and plot line
# (slope, intercept, rvalue, pvalue, stderr) =linregress(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"] )
# regress_values = (northern_hemi_df["Lat"]) * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.plot((northern_hemi_df["Lat"]),regress_values,"r-")
# plt.annotate(line_eq,(5.8,-15),fontsize=15,color="red")

# # Show plot and Pearson r
plt.show()
# correlation = st.pearsonr((northern_hemi_df["Lat"]),northern_hemi_df["Max Temp"])
# print(correlation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # show the plot
# ----> 2 plt.show()
#       4 # # Linear regression on Female Diabetics with scatter plot
#       6 plt.scatter(
#       7      northern_hemi_df["Lat"],
#       8      northern_hemi_df["Max Temp"],
#    (...)
#      13      label="Cities"
#      14  )
#
# NameError: name 'plt' is not defined

# %%
DataFrame.plot.bar(x=age, y=HbA1c_level)




# scatter plot
female_diabetics_df.plot(kind='bar',
        x='age',
        y='HbA1c_level',
        color='red')
 
# set the title
plt.title('Female Diabetics')
 
# show the plot
plt.show()
